# %%
import pandas as pd
pd.set_option("display.max_rows", 1000)
from datetime import datetime, date
import requests
import json

# pull in felony intake data
url="https://datacatalog.cookcountyil.gov/resource/3k7z-hchi.json?$limit=1000000"

request = requests.get(url)
data_dict = json.loads(request.text)

felony_intakes = pd.DataFrame(data_dict)

felony_intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429724 entries, 0 to 429723
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case_id                  429724 non-null  object
#  1   case_participant_id      429724 non-null  object
#  2   received_date            429724 non-null  object
#  3   offense_category         429724 non-null  object
#  4   participant_status       407297 non-null  object
#  5   age_at_incident          407695 non-null  object
#  6   race                     416498 non-null  object
#  7   gender                   418512 non-null  object
#  8   incident_begin_date      411058 non-null  object
#  9   law_enforcement_agency   412059 non-null  object
#  10  arrest_date              389894 non-null  object
#  11  felony_review_date       251224 non-null  object
#  12  felony_review_result     251224 non-null  object
#  13  update_offense_category  429724 non-null  object
#  14  incident_city            412027 non-null  object
#  15  unit                     161051 non-null  object
#  16  incident_end_date        34584 non-null   object
# dtypes: object(17)
# memory usage: 55.7+ MB

# %%
# all of the date columns in here are not date types, let's fix that
intake_cols = felony_intakes.columns

for col in intake_cols:
    if '_date' in col:
        felony_intakes[col] = pd.to_datetime(felony_intakes[col], errors='coerce')
    
# get year from created date
felony_intakes['year'] = felony_intakes['received_date'].dt.year

# %%
# What are the unique values in some of these categorical columns
unique_offense_cat = felony_intakes['offense_category'].unique()
unique_participant_status = felony_intakes['participant_status'].unique()
unique_enforcement_agency = felony_intakes['law_enforcement_agency'].unique()
unique_review_result = felony_intakes['felony_review_result'].unique()
unique_updated_offense = felony_intakes['update_offense_category'].unique()

# %%
# how does this data shake up if we restrict it to only Chicago
chicago_felonies = felony_intakes[felony_intakes['incident_city']=='Chicago']
non_chicago_felonies = felony_intakes[felony_intakes['incident_city']!='Chicago']

# Uncomment to see info
chicago_felonies.info()
#non_chicago_felonies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295042 entries, 7 to 429723
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case_id                  295042 non-null  object
#  1   case_participant_id      295042 non-null  object
#  2   received_date            295042 non-null  datetime64[ns]
#  3   offense_category         295042 non-null  object
#  4   participant_status       282718 non-null  object
#  5   age_at_incident          292078 non-null  object
#  6   race                     288915 non-null  object
#  7   gender                   289602 non-null  object
#  8   incident_begin_date      294474 non-null  datetime64[ns]
#  9   law_enforcement_agency   295042 non-null  object
#  10  arrest_date              273218 non-null  datetime64[ns]
#  11  felony_review_date       157178 non-null  datetime64[ns]
#  12  felony_review_result     157179 non-null  object
#  13  update_offense_category  295042 non-null  object
#  14  incident_city            295042 non-null  object
#  15  unit                     160301 non-null  object
#  16  incident_end_date        18186 non-null   datetime64[ns]
#  17  year                     295042 non-null  int64
# dtypes: datetime64[ns](5), int64(1), object(12)
# memory usage: 42.8+ MB

# %%
# in chicago, what units are charging the most felonies?
chicago_unit_felonies = chicago_felonies.groupby('unit').agg('size').sort_values(ascending=False)
#chicago_unit_felonies

# %%
# in chicago, why are some of the 'unit' fields null?
null_units = chicago_felonies[chicago_felonies['unit'].isna()].reset_index()

# Is it by date?
#print("Null Units by Year")
#print(null_units.groupby('year').agg('size'), "\n")

# Is it by status?
#print("Null Units by Status")
#print(null_units.groupby('participant_status').agg('size').sort_values(ascending=False), "\n")

# Is it by enforcement agency?
#print("Null Units by Enforcement Agency")
#print(null_units.groupby('law_enforcement_agency').agg('size').sort_values(ascending=False), "\n")

# Is it by review result?
#print("Null Units by Review Result")
#print(null_units.groupby('felony_review_result').agg('size').sort_values(ascending=False), "\n")

# Is it by review result?
#print("Null Units by Updated Offense")
#print(null_units.groupby('update_offense_category').agg('size').sort_values(ascending=False), "\n")


### There's about 14,000 arrests that were made in Chicago BUT NOT by CPD. Therefore, unit does not likely apply. 
### Still, null unit rate is about 40% in Chicago arrests

# %%
# what are the unique review results?
print("Unique Review Results\n",unique_review_result)

# subset down to just 'Approved', 'Charges(S) Approved', 'Rejected', & 'Disregard'
statuses = ['Approved','Charge(S) Approved', 'Arrest Warrant', 'Search Warrant','Rejected','Disregard']
rejections = ['Rejected','Disregard']

chicago_felonies[chicago_felonies['felony_review_result'].isin(statuses)]\
        .groupby(['felony_review_result']).agg('size')

chicago_felonies[chicago_felonies['felony_review_result'].isin(rejections)]\
        .groupby(['year', 'unit']).agg('size').sort_values(ascending=False)\
        .sort_index(level='year', sort_remaining=False)
# Out:
# Unique Review Results
#  ['Approved' 'Charge(S) Approved' nan 'Felony Review' 'Rejected'
#  'Continued Investigation' 'Search Warrant' 'Victim Sensitive Interview'
#  'Advice' 'Screen Felony' 'VICTIM SENSITIVE INT' 'Disregard'
#  'Warr Ord Warr Issued' 'Arrest Warrant' 'Deputy Override' 'Warrant Exec'
#  'Chief Judge Assignment To Felony Courtroom']
# year  unit
# 2011  UNIT 079 - SPECIAL INVESTIGATIONS                            64
#       District 6 - Gresham                                         46
#       District 8 - Chicago Lawn                                    35
#       District 3 - Grand Crossing                                  31
#       District 7 - Englewood                                       28
#       District 25 - Grand Central                                  25
#       District 5 - Calumet                                         25
#       District 11 - Harrison                                       20
#       District 15 - Austin                                         20
#       District 9 - Deering                                         20
#       District 1 - Central                                         19
#       UNIT 932 - PATROL AREA 2                                     17
#       District 12 - Monroe                                         17
#       District 4 - South Chicago                                   17
#       District 17 - Albany Park                                    16
#       District 24 - Rogers Park                                    16
#       UNIT 931 - PATROL AREA 1                                     14
#       District 14 - Shakespeare                                    14
#       District 22 - Morgan Park                                    13
#       District 18 - Near North                                     13
#       District 2 - Wentworth                                       12
#       District 10 - Ogden                                          12
#       District 13 - Wood                                           11
#       District 19 - Town Hall                                      10
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        9
#       UNIT 934 - PATROL AREA 4                                      9
#       District 23 - Town Hall                                       9
#       District 21 - Prairie                                         8
#       District 20 - Lincoln                                         8
#       District 16 - Jefferson Park                                  7
#       UNIT 935 - PATROL AREA 5                                      6
#       UNIT 933 - PATROL AREA 3                                      4
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          4
#       UNIT 192 - ASSET FORFEITURE DIVISION                          3
#       UNIT 630 - DETECTIVE SECTION - NORTH                          3
#       UNIT 640 - DET DIV AREA 4                                     2
#       UNIT 652 - VIOLENT CRIMES DDA 5                               2
#       UNIT 311 - GANG ENFORCEMENT - AREA 1                          1
#       UNIT 253 - TARGETED RESPONSE UNIT                             1
#       UNIT 622 - VIOLENT CRIMES DDA 2                               1
#       UNIT 093 - STREET LEVEL ENFORCE                               1
#       UNIT 050 - AIRPORT LAW-NORTH                                  1
#       UNIT 051 - AIRPORT LAW-SOUTH                                  1
#       UNIT 061 - AREA 1 PAT NARC PROG                               1
#       UNIT 650 - DET DIV AREA 5                                     1
#       UNIT 621 - PROP CRIMES DDA 2                                  1
#       UNIT 642 - VIOLENT CRIMES DDA 4                               1
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 153 - MOBILE STRIKE FORCE                                1
#       UNIT 632 - VIOLENT CRIMES DDA 3                               1
#       UNIT 146 - MAJOR ACCIDENT INV                                 1
#       UNIT 075 - YOUTH DIVISION AREA5                               1
# 2012  District 6 - Gresham                                         43
#       District 5 - Calumet                                         31
#       District 7 - Englewood                                       28
#       District 8 - Chicago Lawn                                    27
#       District 3 - Grand Crossing                                  26
#       District 11 - Harrison                                       25
#       District 2 - Wentworth                                       24
#       District 15 - Austin                                         23
#       District 25 - Grand Central                                  23
#       District 1 - Central                                         20
#       District 18 - Near North                                     19
#       District 9 - Deering                                         18
#       District 10 - Ogden                                          17
#       District 17 - Albany Park                                    14
#       District 4 - South Chicago                                   13
#       District 22 - Morgan Park                                    13
#       District 14 - Shakespeare                                    10
#       UNIT 079 - SPECIAL INVESTIGATIONS                            10
#       District 16 - Jefferson Park                                  9
#       UNIT 630 - DETECTIVE SECTION - NORTH                          8
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        7
#       District 20 - Lincoln                                         6
#       District 19 - Town Hall                                       6
#       District 24 - Rogers Park                                     5
#       District 12 - Monroe                                          5
#       UNIT 622 - VIOLENT CRIMES DDA 2                               4
#       District 13 - Wood                                            3
#       District 21 - Prairie                                         3
#       District 23 - Town Hall                                       1
#       UNIT 050 - AIRPORT LAW-NORTH                                  1
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 193 - GANG INTELLIGENCE DIVISION                         1
#       UNIT 312 - GANG ENFORCEMENT - AREA 2                          1
#       UNIT 612 - VIOLENT CRIMES DDA 1                               1
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          1
#       UNIT 640 - DET DIV AREA 4                                     1
#       UNIT 650 - DET DIV AREA 5                                     1
# 2013  District 6 - Gresham                                         38
#       District 7 - Englewood                                       32
#       District 5 - Calumet                                         25
#       District 8 - Chicago Lawn                                    22
#       District 9 - Deering                                         21
#       District 3 - Grand Crossing                                  18
#       District 2 - Wentworth                                       18
#       District 10 - Ogden                                          18
#       District 11 - Harrison                                       17
#       District 25 - Grand Central                                  17
#       District 15 - Austin                                         14
#       District 4 - South Chicago                                   14
#       District 19 - Town Hall                                      13
#       District 22 - Morgan Park                                    12
#       District 12 - Monroe                                         11
#       District 18 - Near North                                     10
#       District 20 - Lincoln                                         8
#       District 1 - Central                                          7
#       District 16 - Jefferson Park                                  7
#       District 14 - Shakespeare                                     6
#       District 17 - Albany Park                                     6
#       District 24 - Rogers Park                                     6
#       UNIT 079 - SPECIAL INVESTIGATIONS                             5
#       UNIT 630 - DETECTIVE SECTION - NORTH                          4
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        1
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          1
# 2014  District 6 - Gresham                                         35
#       District 7 - Englewood                                       31
#       District 4 - South Chicago                                   29
#       District 9 - Deering                                         29
#       District 5 - Calumet                                         29
#       District 3 - Grand Crossing                                  27
#       District 10 - Ogden                                          24
#       District 15 - Austin                                         23
#       District 11 - Harrison                                       23
#       District 22 - Morgan Park                                    20
#       District 1 - Central                                         19
#       District 8 - Chicago Lawn                                    16
#       District 25 - Grand Central                                  16
#       District 12 - Monroe                                         15
#       District 24 - Rogers Park                                    10
#       District 2 - Wentworth                                        9
#       District 17 - Albany Park                                     8
#       District 16 - Jefferson Park                                  8
#       District 18 - Near North                                      7
#       District 14 - Shakespeare                                     6
#       District 19 - Town Hall                                       4
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          4
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        4
#       UNIT 050 - AIRPORT LAW-NORTH                                  3
#       UNIT 630 - DETECTIVE SECTION - NORTH                          3
#       UNIT 079 - SPECIAL INVESTIGATIONS                             2
#       District 20 - Lincoln                                         1
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 193 - GANG INTELLIGENCE DIVISION                         1
#       UNIT 311 - GANG ENFORCEMENT - AREA 1                          1
# 2015  District 4 - South Chicago                                   39
#       District 6 - Gresham                                         34
#       District 15 - Austin                                         29
#       District 11 - Harrison                                       24
#       District 10 - Ogden                                          22
#       District 3 - Grand Crossing                                  22
#       District 25 - Grand Central                                  22
#       District 5 - Calumet                                         19
#       District 7 - Englewood                                       19
#       District 18 - Near North                                     19
#       District 9 - Deering                                         18
#       District 1 - Central                                         18
#       District 8 - Chicago Lawn                                    16
#       District 2 - Wentworth                                       14
#       District 22 - Morgan Park                                    13
#       District 12 - Monroe                                         12
#       District 19 - Town Hall                                      11
#       District 24 - Rogers Park                                    10
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                       10
#       District 16 - Jefferson Park                                  9
#       UNIT 079 - SPECIAL INVESTIGATIONS                             9
#       District 17 - Albany Park                                     8
#       UNIT 630 - DETECTIVE SECTION - NORTH                          7
#       District 20 - Lincoln                                         7
#       District 14 - Shakespeare                                     7
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          4
#       UNIT 051 - AIRPORT LAW-SOUTH                                  1
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 212 - DEPUTY CHIEF AREA SOUTH                            1
#       UNIT 606 - CENTRAL HOMICIDE - EVALUATION AND SUPPORT UNIT     1
#       UNIT 609 - FINANCIAL CRIMES INVESTIGATIONS                    1
# 2016  District 3 - Grand Crossing                                  27
#       District 11 - Harrison                                       24
#       District 6 - Gresham                                         22
#       District 5 - Calumet                                         21
#       District 8 - Chicago Lawn                                    21
#       District 4 - South Chicago                                   19
#       District 12 - Monroe                                         18
#       District 7 - Englewood                                       17
#       District 25 - Grand Central                                  17
#       District 15 - Austin                                         17
#       District 2 - Wentworth                                       15
#       District 1 - Central                                         14
#       District 9 - Deering                                         14
#       UNIT 079 - SPECIAL INVESTIGATIONS                            13
#       District 22 - Morgan Park                                    12
#       District 18 - Near North                                     12
#       District 10 - Ogden                                          11
#       District 14 - Shakespeare                                    11
#       District 19 - Town Hall                                      10
#       District 20 - Lincoln                                         9
#       District 16 - Jefferson Park                                  9
#       District 17 - Albany Park                                     7
#       UNIT 630 - DETECTIVE SECTION - NORTH                          6
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          5
#       District 24 - Rogers Park                                     5
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        4
#       UNIT 050 - AIRPORT LAW-NORTH                                  3
#       UNIT 193 - GANG INTELLIGENCE DIVISION                         2
#       District 13 - Wood                                            2
#       UNIT 608 - MAJOR ACCIDENT INVESTIGATION                       1
#       UNIT 606 - CENTRAL HOMICIDE - EVALUATION AND SUPPORT UNIT     1
#       UNIT 051 - AIRPORT LAW-SOUTH                                  1
#       UNIT 311 - GANG ENFORCEMENT - AREA 1                          1
#       UNIT 312 - GANG ENFORCEMENT - AREA 2                          1
# 2017  District 1 - Central                                         34
#       District 6 - Gresham                                         32
#       District 2 - Wentworth                                       29
#       District 18 - Near North                                     26
#       District 25 - Grand Central                                  26
#       District 10 - Ogden                                          21
#       District 5 - Calumet                                         20
#       District 9 - Deering                                         20
#       District 7 - Englewood                                       19
#       District 11 - Harrison                                       19
#       District 19 - Town Hall                                      18
#       District 4 - South Chicago                                   17
#       District 12 - Monroe                                         14
#       District 8 - Chicago Lawn                                    14
#       District 3 - Grand Crossing                                  14
#       District 15 - Austin                                         12
#       UNIT 079 - SPECIAL INVESTIGATIONS                            10
#       District 17 - Albany Park                                    10
#       District 20 - Lincoln                                        10
#       District 24 - Rogers Park                                     9
#       District 22 - Morgan Park                                     9
#       District 14 - Shakespeare                                     6
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          5
#       District 16 - Jefferson Park                                  5
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        4
#       UNIT 630 - DETECTIVE SECTION - NORTH                          3
#       UNIT 212 - DEPUTY CHIEF AREA SOUTH                            2
#       UNIT 313 - GANG ENFORCEMENT - AREA 3                          2
#       UNIT 193 - GANG INTELLIGENCE DIVISION                         1
#       UNIT 211 - DEPUTY CHIEF AREA CENTRAL                          1
#       UNIT 213 - DEPUTY CHIEF AREA NORTH                            1
#       UNIT 191 - INTELLIGENCE                                       1
#       UNIT 189 - NARCOTICS                                          1
# 2018  District 6 - Gresham                                         39
#       District 18 - Near North                                     39
#       District 1 - Central                                         36
#       District 7 - Englewood                                       24
#       District 12 - Monroe                                         24
#       District 10 - Ogden                                          23
#       District 25 - Grand Central                                  22
#       District 8 - Chicago Lawn                                    17
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                       16
#       District 24 - Rogers Park                                    16
#       District 14 - Shakespeare                                    16
#       District 19 - Town Hall                                      16
#       District 5 - Calumet                                         15
#       District 4 - South Chicago                                   15
#       District 11 - Harrison                                       15
#       District 2 - Wentworth                                       13
#       UNIT 630 - DETECTIVE SECTION - NORTH                         11
#       District 17 - Albany Park                                    11
#       District 15 - Austin                                         11
#       District 3 - Grand Crossing                                  10
#       District 20 - Lincoln                                        10
#       District 9 - Deering                                         10
#       UNIT 079 - SPECIAL INVESTIGATIONS                             9
#       District 16 - Jefferson Park                                  5
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          3
#       District 22 - Morgan Park                                     3
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 312 - GANG ENFORCEMENT - AREA 2                          1
# 2019  District 18 - Near North                                     63
#       District 1 - Central                                         61
#       District 6 - Gresham                                         50
#       District 3 - Grand Crossing                                  35
#       District 2 - Wentworth                                       34
#       District 10 - Ogden                                          32
#       District 4 - South Chicago                                   30
#       District 12 - Monroe                                         27
#       District 7 - Englewood                                       27
#       District 8 - Chicago Lawn                                    27
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                       27
#       District 19 - Town Hall                                      26
#       District 14 - Shakespeare                                    23
#       District 22 - Morgan Park                                    21
#       District 24 - Rogers Park                                    19
#       District 25 - Grand Central                                  19
#       District 11 - Harrison                                       17
#       UNIT 630 - DETECTIVE SECTION - NORTH                         15
#       District 9 - Deering                                         13
#       UNIT 620 - DETECTIVE SECTION - SOUTH                         11
#       District 16 - Jefferson Park                                 11
#       District 17 - Albany Park                                    10
#       District 15 - Austin                                         10
#       District 5 - Calumet                                         10
#       District 20 - Lincoln                                         5
#       UNIT 311 - GANG ENFORCEMENT - AREA 1                          1
#       UNIT 050 - AIRPORT LAW-NORTH                                  1
#       UNIT 051 - AIRPORT LAW-SOUTH                                  1
#       UNIT 079 - SPECIAL INVESTIGATIONS                             1
#       UNIT 189 - NARCOTICS                                          1
#       UNIT 213 - DEPUTY CHIEF AREA NORTH                            1
#       UNIT 313 - GANG ENFORCEMENT - AREA 3                          1
#       UNIT 609 - FINANCIAL CRIMES INVESTIGATIONS                    1
# 2020  District 1 - Central                                         18
#       District 11 - Harrison                                       16
#       District 8 - Chicago Lawn                                    15
#       District 6 - Gresham                                         14
#       District 10 - Ogden                                          13
#       District 18 - Near North                                     13
#       District 25 - Grand Central                                  12
#       District 7 - Englewood                                       12
#       District 15 - Austin                                         12
#       District 9 - Deering                                         11
#       District 12 - Monroe                                          9
#       District 17 - Albany Park                                     9
#       District 4 - South Chicago                                    9
#       District 2 - Wentworth                                        8
#       District 14 - Shakespeare                                     8
#       District 5 - Calumet                                          8
#       District 16 - Jefferson Park                                  6
#       District 3 - Grand Crossing                                   6
#       District 19 - Town Hall                                       5
#       District 22 - Morgan Park                                     5
#       District 24 - Rogers Park                                     5
#       UNIT 051 - AIRPORT LAW-SOUTH                                  2
#       District 20 - Lincoln                                         1
#       UNIT 312 - GANG ENFORCEMENT - AREA 2                          1
#       UNIT 610 - DETECTIVE SECTION - CENTRAL                        1
#       UNIT 620 - DETECTIVE SECTION - SOUTH                          1
# 2021  District 1 - Central                                          5
#       District 6 - Gresham                                          4
#       District 3 - Grand Crossing                                   4
#       District 11 - Harrison                                        3
#       District 12 - Monroe                                          3
#       District 18 - Near North                                      2
#       District 8 - Chicago Lawn                                     2
#       District 9 - Deering                                          2
#       District 15 - Austin                                          2
#       UNIT 313 - GANG ENFORCEMENT - AREA 3                          1
#       District 10 - Ogden                                           1
#       District 14 - Shakespeare                                     1
#       District 17 - Albany Park                                     1
#       District 2 - Wentworth                                        1
#       District 5 - Calumet                                          1
#       UNIT 050 - AIRPORT LAW-NORTH                                  1
# dtype: int64
