# %%
import pandas as pd
pd.set_option("display.max_rows", 1000)
from datetime import datetime, date
import requests
import json

# pull in felony intake data
url="https://datacatalog.cookcountyil.gov/resource/3k7z-hchi.json?$limit=1000000"

request = requests.get(url)
data_dict = json.loads(request.text)

felony_intakes = pd.DataFrame(data_dict)

felony_intakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429724 entries, 0 to 429723
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case_id                  429724 non-null  object
#  1   case_participant_id      429724 non-null  object
#  2   received_date            429724 non-null  object
#  3   offense_category         429724 non-null  object
#  4   participant_status       407297 non-null  object
#  5   age_at_incident          407695 non-null  object
#  6   race                     416498 non-null  object
#  7   gender                   418512 non-null  object
#  8   incident_begin_date      411058 non-null  object
#  9   law_enforcement_agency   412059 non-null  object
#  10  arrest_date              389894 non-null  object
#  11  felony_review_date       251224 non-null  object
#  12  felony_review_result     251224 non-null  object
#  13  update_offense_category  429724 non-null  object
#  14  incident_city            412027 non-null  object
#  15  unit                     161051 non-null  object
#  16  incident_end_date        34584 non-null   object
# dtypes: object(17)
# memory usage: 55.7+ MB

# %%
# all of the date columns in here are not date types, let's fix that
intake_cols = felony_intakes.columns

for col in intake_cols:
    if '_date' in col:
        felony_intakes[col] = pd.to_datetime(felony_intakes[col], errors='coerce')
    
felony_intakes
# Out:
#              case_id case_participant_id received_date  \
# 0       217923815445        209352968780    2011-05-24
# 1       217923815445        209353063152    2011-05-24
# 2       217923815445        209353157524    2011-05-24
# 3       223435124424        219042164387    2012-01-27
# 4       236914327334        218815387947    2011-01-31
# ...              ...                 ...           ...
# 429719  446279599359        907765702925    2021-03-31
# 429720  446279746213        907765986042    2021-03-31
# 429721  446279746213        907766080414    2021-03-31
# 429722  446279893068        907766552275    2021-03-31
# 429723  446280039923        907767307253    2021-04-01
#
#                     offense_category       participant_status age_at_incident  \
# 0                  PROMIS Conversion  Continued Investigation              25
# 1                  PROMIS Conversion                 Approved              22
# 2                  PROMIS Conversion  Continued Investigation              19
# 3                  PROMIS Conversion                 Approved             NaN
# 4                  PROMIS Conversion                 Approved              37
# ...                              ...                      ...             ...
# 429719  UUW - Unlawful Use of Weapon                 Approved              22
# 429720  UUW - Unlawful Use of Weapon                 Approved              30
# 429721  UUW - Unlawful Use of Weapon                 Approved              28
# 429722  UUW - Unlawful Use of Weapon                      NaN              29
# 429723  UUW - Unlawful Use of Weapon                 Approved              28
#
#             race  gender incident_begin_date           law_enforcement_agency  \
# 0          Black    Male          2007-03-12           PROMIS Data Conversion
# 1          Black    Male          2007-03-12           PROMIS Data Conversion
# 2          Black    Male          2007-03-12           PROMIS Data Conversion
# 3          Black    Male          2009-06-25               CPD SPEC INV-YOUTH
# 4       HISPANIC    Male          2010-04-07                 SPEC. OPERATIONS
# ...          ...     ...                 ...                              ...
# 429719     Black    Male          2021-03-31                       CHICAGO PD
# 429720     Black    Male          2021-03-31  COOK COUNTY SHERIFF (IL0160000)
# 429721     Black    Male          2021-03-31  COOK COUNTY SHERIFF (IL0160000)
# 429722     Black    Male          2021-03-31             ISP DISTRICT CHICAGO
# 429723     Black  Female          2021-03-31                       CHICAGO PD
#
#                arrest_date felony_review_date     felony_review_result  \
# 0      2007-04-03 00:00:00         2011-05-24                 Approved
# 1      2011-05-22 18:51:00         2011-05-24                 Approved
# 2                      NaT         2011-05-24                 Approved
# 3      2009-07-14 14:34:00         2009-07-14       Charge(S) Approved
# 4      2010-04-07 20:40:00                NaT                      NaN
# ...                    ...                ...                      ...
# 429719 2021-03-31 19:57:00                NaT                      NaN
# 429720 2021-03-31 21:05:00         2021-04-01                 Approved
# 429721 2021-03-31 21:05:00         2021-04-01                 Approved
# 429722                 NaT         2021-04-01  Continued Investigation
# 429723 2021-03-31 12:29:00         2021-04-01                 Approved
#
#              update_offense_category incident_city unit incident_end_date
# 0                           Homicide           NaN  NaN               NaT
# 1                           Homicide           NaN  NaN               NaT
# 2                           Homicide           NaN  NaN               NaT
# 3                   Attempt Homicide           NaN  NaN               NaT
# 4                          Narcotics           NaN  NaN               NaT
# ...                              ...           ...  ...               ...
# 429719  UUW - Unlawful Use of Weapon       Chicago  NaN               NaT
# 429720  UUW - Unlawful Use of Weapon       Chicago  NaN               NaT
# 429721  UUW - Unlawful Use of Weapon       Chicago  NaN               NaT
# 429722  UUW - Unlawful Use of Weapon       Chicago  NaN               NaT
# 429723  UUW - Unlawful Use of Weapon       Chicago  NaN               NaT
#
# [429724 rows x 17 columns]

# %%
# What are the unique values in some of these categorical columns
unique_offense_cat = felony_intakes['offense_category'].unique()
unique_participant_status = felony_intakes['participant_status'].unique()
unique_enforcement_agency = felony_intakes['law_enforcement_agency'].unique()
unique_review_result = felony_intakes['felony_review_result'].unique()
unique_updated_offense = felony_intakes['update_offense_category'].unique()

# %%
# how does this data shake up if we restrict it to only Chicago
chicago_felonies = felony_intakes[felony_intakes['incident_city']=='Chicago']
non_chicago_felonies = felony_intakes[felony_intakes['incident_city']!='Chicago']

# Uncomment to see info
chicago_felonies.info()
#non_chicago_felonies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295042 entries, 7 to 429723
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case_id                  295042 non-null  object
#  1   case_participant_id      295042 non-null  object
#  2   received_date            295042 non-null  datetime64[ns]
#  3   offense_category         295042 non-null  object
#  4   participant_status       282718 non-null  object
#  5   age_at_incident          292078 non-null  object
#  6   race                     288915 non-null  object
#  7   gender                   289602 non-null  object
#  8   incident_begin_date      294474 non-null  datetime64[ns]
#  9   law_enforcement_agency   295042 non-null  object
#  10  arrest_date              273218 non-null  datetime64[ns]
#  11  felony_review_date       157178 non-null  datetime64[ns]
#  12  felony_review_result     157179 non-null  object
#  13  update_offense_category  295042 non-null  object
#  14  incident_city            295042 non-null  object
#  15  unit                     160301 non-null  object
#  16  incident_end_date        18186 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), object(12)
# memory usage: 40.5+ MB

# %%
# in chicago, what units are charging the most felonies?
chicago_unit_felonies = chicago_felonies.groupby('unit').agg('size').sort_values(ascending=False)
#chicago_unit_felonies

# %%
# in chicago, why are some of the 'unit' fields null?
null_units = chicago_felonies[chicago_felonies['unit'].isna()].reset_index()

# get year from created date
null_units['year'] = null_units['received_date'].dt.year

# Is it by date?
#print("Null Units by Year")
#print(null_units.groupby('year').agg('size'), "\n")

# Is it by status?
#print("Null Units by Status")
#print(null_units.groupby('participant_status').agg('size').sort_values(ascending=False), "\n")

# Is it by enforcement agency?
#print("Null Units by Enforcement Agency")
#print(null_units.groupby('law_enforcement_agency').agg('size').sort_values(ascending=False), "\n")

# Is it by review result?
#print("Null Units by Review Result")
#print(null_units.groupby('felony_review_result').agg('size').sort_values(ascending=False), "\n")

# Is it by review result?
#print("Null Units by Updated Offense")
#print(null_units.groupby('update_offense_category').agg('size').sort_values(ascending=False), "\n")


### There's about 14,000 arrests that were made in Chicago BUT NOT by CPD. Therefore, unit does not likely apply. 
### Still, null unit rate is about 40% in Chicago arrests
# Out:
# Null Units by Enforcement Agency
# law_enforcement_agency
# CHICAGO PD                                                      120827
# COOK COUNTY SHERIFF (IL0160000)                                   6446
# ISP DISTRICT CHICAGO                                              1370
# U OF I POLICE DEPARTMENT CHICAGO                                   767
# ISP DISTRICT 03                                                    726
# COOK COUNTY DEPT. OF CORRECTIONS                                   470
# UNIVERSITY OF CHICAGO POLICE DEPT                                  297
# CICERO PD                                                          227
# AMTRAK NATIONAL RAILROAD PASSENGER CORP                            222
# ISP DISTRICT 01                                                    201
# METRA PD                                                           196
# EVERGREEN PARK PD                                                  158
# COOK COUNTY SHERIFF'S FUGITIVE-WARRANTS (IL0169Q00)                148
# COOK COUNTY SHERIFF'S POLICE PATROL MAYWOOD (IL01600Y2)            139
# CHICAGO HEIGHTS PD                                                 135
# EVANSTON PD                                                        131
# US DEA CHICAGO DEARBORN                                            122
# COOK COUNTY STATE'S ATTORNEY'S OFFICE                              109
# OAK PARK PD                                                         90
# COOK COUNTY SHERIFF'S POLICE PATROL CRIM CT (IL016B200)             89
# IL STATE POLICE PROTECTIVE SERVICE                                  70
# FBI, CHICAGO                                                        58
# CHICAGO RIDGE PD                                                    51
# COOK COUNTY SHERIFF'S GANGS (IL01600E8)                             49
# COOK COUNTY FOREST PRESERVE POLICE DEPT                             44
# US DEPT OF HOUSING & URBAN DEVELOPMENT/OFFICE OF THE INSPECT        43
# DES PLAINES PD                                                      39
# SKOKIE PD                                                           39
# US ATFE JUSTICE, CHICAGO                                            38
# COOK COUNTY JOHN STROGER HSPTL POLICE DEPARTMENT                    37
# JUSTICE PD                                                          36
# HANOVER PARK PD                                                     35
# ELMWOOD PARK PD                                                     34
# ISP DISTRICT 15                                                     34
# COOK COUNTY SHERIFF'S POLICE PATROL BRIDGEVIEW (IL016A700)          33
# COOK COUNTY SHERIFF'S POLICE VICE/SPECIAL OPS (IL01600D5)           30
# WILMETTE PD                                                         30
# SEC. OF STATE POLICE                                                29
# ISP DOO ZONE 1, DES PLAINES                                         29
# HARWOOD HEIGHTS PD                                                  27
# Dept of Veterans Affairs, Office of Inspector General               26
# BERWYN PD                                                           26
# IL SOS DISTRICT 1 VILLA PARK                                        24
# COOK COUNTY SHERIFF'S PATROL DESK (IL01600E9)                       22
# ISP NE METRO AUTO THEFT                                             21
# CHICAGO STATE UNIV PD                                               20
# FOREST PARK PD                                                      20
# NORFOLK AND SOUTHERN RAILWAY PD                                     20
# OAK LAWN PD                                                         19
# NORRIDGE PD                                                         19
# U.S. DEPARTMENT OF HOMELAND SECURITY (Chicago)                      19
# BLUE ISLAND PD                                                      18
# ISP DII DES PLAINES                                                 18
# NORTHEASTERN ILL UNIV POLICE DEPT                                   17
# SUMMIT PD                                                           17
# ISP N CENTRAL NARCOTICS TASK FORCE                                  17
# GLENVIEW PD                                                         17
# NILES PD                                                            17
# LINCOLNWOOD PD                                                      16
# RIVER FOREST PD                                                     16
# COOK COUNTY SHERIFF'S WARRANTS - MAYWOOD (IL0160011)                15
# BURBANK PD                                                          15
# NORTHBROOK PD                                                       15
# US POSTAL INSPECTION SERVICE                                        15
# FRANKLIN PARK PD                                                    14
# DOLTON PD                                                           14
# COOK COUNTY SHERIFF'S POLICE PATROL MARKHAM (IL016B100)             14
# US DVA MED CENTER W. CHICAGO                                        14
# BEDFORD PARK PD                                                     12
# PARK RIDGE PD                                                       12
# ORLAND PARK PD                                                      12
# NORTHLAKE PD                                                        12
# IL SOS DISTRICT 3                                                   12
# MORTON GROVE PD                                                     11
# ROSEMONT PD                                                         11
# HOFFMAN ESTATES PD                                                  11
# PARK FOREST PD                                                      11
# TINLEY PARK PD                                                      10
# WINNETKA PD                                                         10
# IL ATTORNEY GENERAL, CHICAGO                                        10
# RIVERDALE PD                                                        10
# HOMETOWN PD                                                          9
# ILLINOIS CONSERVATION POLICE, REGION 2                               9
# HARVEY PD                                                            8
# ISP DUPAGE MEG                                                       8
# SCHILLER PARK PD                                                     8
# CHICAGO PD - AREA CENTRAL                                            8
# CHICAGO PD - AREA NORTH                                              8
# ISP DISTRICT 02                                                      8
# ISP DISTRICT 16                                                      8
# MAYWOOD PD                                                           8
# CROSSROADS ADULT TRANSITION CENTER                                   8
# CALUMET CITY PD                                                      8
# ISP DISTRICT 11                                                      8
# US DEA DES PLAINES                                                   8
# CHICAGO PD - AREA SOUTH                                              7
# IDOC ADULT PAROLE DIVISION                                           7
# ALSIP PD                                                             7
# ISP INV DCHGO, DES PLAINES                                           7
# SAUK VILLAGE PD                                                      7
# US DHS ICE OAKBROOK TERRACE                                          6
# BURLINGTON NORTHERN SANTA FE RAILROAD PD                             6
# CALUMET PARK PD                                                      6
# BURNHAM PD                                                           6
# ISP DISTRICT 05                                                      6
# IDOC, FUGITIVE APPREHENSION UNIT - DISTRICT1                         6
# MELROSE PARK PD                                                      5
# COOK COUNTY SHERIFF'S CRT SRVCS - MAYWOOD (IL01600X9)                5
# SCHAUMBURG PD                                                        5
# MATTESON PD                                                          5
# IDOC WEST SIDE CHICAGO                                               5
# US DVA MED CENTER POLICE N CHGO                                      5
# IL SOS AUTO THEFT AREA 1 JOLIET                                      4
# NAPERVILLE PD                                                        4
# BROADVIEW PD                                                         4
# POSEN PD                                                             4
# BROOKFIELD PD                                                        4
# MC COOK PD                                                           4
# ISP DOO ZONE 3, LOCKPORT                                             4
# LYNWOOD PD                                                           4
# ARLINGTON HEIGHTS PD                                                 4
# STONE PARK PD                                                        4
# PALATINE PD                                                          3
# US DHS ICE 10 WEST JACKSON                                           3
# HODGKINS PD                                                          3
# COOK COUNTY SHERIFF'S POLICE PATROL ROLL MEADOWS (IL016A800)         3
# COOK COUNTY SHERIFF'S SKOKIE INVESTIGATION                           3
# COOK COUNTY, OFFICE OF THE INSPECTOR GENERAL                         3
# COUNTRYSIDE PD                                                       3
# DIXMOOR PD                                                           3
# RICHTON PARK PD                                                      3
# SOUTH BARRINGTON PD                                                  3
# STREAMWOOD PD                                                        3
# GLENCOE PD                                                           3
# STICKNEY PD                                                          3
# ROLLING MEADOWS PD                                                   3
# SOUTH HOLLAND PD                                                     3
# PHOENIX PD                                                           3
# HOMEWOOD PD                                                          3
# ISP METRO ENF GROUP OF LAKE COUNTY                                   3
# IDOC SPRINGFIELD OPERATIONS CENTER                                   3
# LYONS PD                                                             3
# ISP DII TINLEY PARK                                                  3
# CHICAGO TRANSIT AUTH, INSP GENERAL                                   3
# ISP DISTRICT 09                                                      3
# NORTH RIVERSIDE PD                                                   3
# IDOC STATEVILLE                                                      3
# LANSING PD                                                           3
# ISP PROTECTIVE SERVICES UNIT                                         3
# LA GRANGE PARK PD                                                    2
# BURR RIDGE PD                                                        2
# ISP NARCOTICS AND CURRENCY INTERDICTION UNIT [NARCINT]               2
# DEERFIELD PD                                                         2
# ISP DISTRICT 22                                                      2
# US DEPT OF JUSTICE, OFFICE INSP GENERAL                              2
# WESTCHESTER PD                                                       2
# BELLWOOD PD                                                          2
# BARRINGTON HILLS PD                                                  2
# ISP DOO STATE FINANCIAL CRIME                                        2
# ELGIN PD                                                             2
# ELK GROVE VILLAGE PD                                                 2
# IDOC COMMUNITY SERVICES PLACEMENT UNIT                               2
# HICKORY HILLS PD                                                     2
# HAZEL CREST PD                                                       2
# PALOS HILLS PD                                                       2
# OLYMPIA FIELDS PD                                                    2
# IDOC PAROLE SUPERVISOR                                               2
# IDOC PONTIAC                                                         2
# HILLSIDE PD                                                          2
# LOYOLA UNIVERSITY OF CHICAGO PD                                      2
# ISP DISTRICT 07                                                      2
# NORTHWESTERN UNIVERSITY POLICE DEPT.                                 2
# BRIDGEVIEW PD                                                        2
# IL SOS DISTRICT 2                                                    2
# MERRIONETTE PARK PD                                                  2
# MARKHAM PD                                                           2
# C P D AREA 4 VC                                                      1
# BARRINGTON PD                                                        1
# CANADIAN NATIONAL RAILROAD POLICE                                    1
# BERKELEY PD                                                          1
# COOK COUNTY SHERIFF'S POLICE PATROL - DOM VIOL (IL016B300)           1
# CAROL STREAM PD                                                      1
# WORTH PD                                                             1
# COOK COUNTY SHERIFF'S POLICE PATROL DESPLAINES (IL016A900)           1
# EAST HAZELCREST PD                                                   1
# LEMONT PD                                                            1
# LISLE PD                                                             1
# MIDLOTHIAN PD                                                        1
# OAK FOREST PD                                                        1
# PALOS HEIGHTS PD                                                     1
# PLAINFIELD PD                                                        1
# PROSPECT HEIGHTS PD                                                  1
# RIVER GROVE PD                                                       1
# RIVERSIDE PD                                                         1
# SOUTH CHICAGO HEIGHTS PD                                             1
# U.S. Department of Homeland Security, Office Inspctr General         1
# US ATFE JUSTICE, DOWNERS GROVE                                       1
# US POSTAL INSPECTION SERVICE, O'HARE                                 1
# US SECRET SERVICE, CHICAGO                                           1
# WESTERN SPRINGS PD                                                   1
# WHEATON PD                                                           1
# WHEELING PD                                                          1
# LEAD Complaint Form                                                  1
# ISP MOTORCYCLE ENFORCEMENT BUREAU                                    1
# ISP ITC FIREARMS SERVICES BUREAU                                     1
# IL SOS SUPPORT SERVICES                                              1
# ELMHURST POLICE DEPARTMENT                                           1
# FLOSSMOOR PD                                                         1
# GLENWOOD PD                                                          1
# HINSDALE PD                                                          1
# IDOC JOLIET                                                          1
# IL Dept OF Revenue, Criminal Investigation Division                  1
# IL SOS POLICE INQUIRY UNIT                                           1
# IL SOS VEH INSP VILLA PARK                                           1
# ISP GAMING BOARD, CHICAGO                                            1
# ISP CRITICAL INCIDENT RESPONSE COMMAND                               1
# ISP DISTRICT 12                                                      1
# ISP DISTRICT 19                                                      1
# ISP DIVISION OF FORENSIC SERVICES                                    1
# ISP DOO OPERATIONAL SERVICES COMMAND                                 1
# ISP DOO ZONE 1, DOWNERS GROVE                                        1
# ISP DOO ZONE 4, PITTSFIELD                                           1
# ISP DISTRICT 08                                                      1
# dtype: int64
